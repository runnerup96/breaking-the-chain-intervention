# %%
import os
import json
from averitec_dataset import AVeriTeCDataset

path = '/home/chaichuk/frontdoor_llm_causality/intervention_analysis/intervention_predictions/averitec'
files = os.listdir(path)

dataset = AVeriTeCDataset('/home/chaichuk/frontdoor_llm_causality/statics/datasets/AVeriTeC/data')

for file in files:
    data = None
    with open(f'{path}/{file}', 'r', encoding='utf-8') as f:
        data = json.load(f)

    if 'result' not in data:
        continue

    generated = {}

    for i in range(len(data['result'])):
        if data['result'][i]['completion_type'] == 'gold_structure':
            continue
        idx = data['result'][i]['idx']
        supporting_questions = data['result'][i]['supporting_questions']
        label = data['result'][i]["label"]

        generated[idx] = {'supporting_questions': supporting_questions, 'label': label}

    
    new_data = {}

    for i in range(len(dataset)):
        golden = dataset[i]
        idx = golden['idx']
        if idx not in generated:
            continue
        gen = generated[idx]
        if gen['supporting_questions'] == {}:
            continue

        if gen['supporting_questions'] != golden['supporting_questions']:
            new_data[idx] = {'claim': golden['claim'],
                             'explanations': golden['explanations'],
                             'golden_supporting_questions': golden['supporting_questions'],
                             'golden_label': golden['label'],
                             'bad_supporting_questions': gen['supporting_questions'],
                             'bad_label': gen['label']}
            
    print(file, len(new_data))
            
    with open(f'/home/chaichuk/frontdoor_llm_causality/statics/datasets/averitec_correction/{file}', 'w', encoding='utf-8') as f:
        json.dump(new_data, f, indent=4, ensure_ascii=False)
# Out:
# qwen3-4B.json 30
# gemma2-2B.json 45
# falcon3-7B.json 17
# llama31-8B.json 27
# falcon3-3B.json 26
# qwen3-8B.json 24
# llama32-3B.json 51
# llama32-1B.json 95
# qwen3-17B.json 38

# %%
import os
import json

path = '/home/chaichuk/frontdoor_llm_causality/intervention_analysis/intervention_predictions/ricechem'
files = os.listdir(path)

for file in files:
    data = None
    with open(f'{path}/{file}', 'r', encoding='utf-8') as f:
        data = json.load(f)

    if 'result' not in data:
        continue

    generated = {}

    for i in range(len(data['result'])):
        if data['result'][i]['completion_type'] == 'gold_structure':
            continue
        idx = data['result'][i]['idx']
        filled_rubric = data['result'][i]['filled_rubric']
        score = data['result'][i]['score']

        generated[idx] = {'filled_rubric': filled_rubric, 'score': score}

    
    new_data = {}

    for i in range(len(dataset)):
        golden = dataset[i]
        idx = golden['idx']
        if idx not in generated:
            continue
        gen = generated[idx]
        if gen['filled_rubric'] == {}:
            continue

        if set(gen['filled_rubric'].keys()) != set(golden['filled_rubric'].keys()):
            continue

        if gen['filled_rubric'] != golden['filled_rubric']:
            new_data[idx] = {'task_idx': golden['task_idx'], 
                             'task': golden['task'],
                             'score_range': golden['score_range'],
                             'student_answer': golden['student_answer'],
                             'golden_rubric': golden['filled_rubric'],
                             'golden_score': golden['score'],
                             'bad_rubric': gen['filled_rubric'],
                             'bad_score': gen['score']}
            
    print(file, len(new_data))
            
    with open(f'/home/chaichuk/frontdoor_llm_causality/statics/datasets/ricechem_correction/{file}', 'w', encoding='utf-8') as f:
        json.dump(new_data, f, indent=4, ensure_ascii=False)
# Out:
# qwen3-4B.json 918
# falcon3-7B.json 958
# llama31-8B.json 167
# {'Sentence 2: Correct number of hybrid orbitals. In this molecule, carbon must form three hybrid orbitals to form three electron domains.': True, 'Sentence 2: Correct type of hybrid orbitals. Carbon must form sp2 hybrid orbitals (from using a 2s and two 2p orbitals)': True, 'Sentence 3: Correctly states that nitrogen is hybridized': True, 'Sentence 3: Correct type of hybridization. Nitrogen is sp2 hybridized to form 3 electron domains': True, 'Sentence 3: Correct description of hybrid orbital bonds in nitrogen. Two sp2 orbitals form two sigma bonds.': True, 'Sentence 3: Correct description of unhybridized orbital bonds in nitrogen. Unhybridized p orbital forms pi bond': True}
# {'Sentence 1 is correct. Valence bond theory describes that atomic orbitals must be half-filled to participate in covalent bonding.': True, 'Sentence 2: Correct number of hybrid orbitals. In this molecule, carbon must form three hybrid orbitals to form three electron domains.': False, 'Sentence 2: Correct type of hybrid orbitals. Carbon must form sp2 hybrid orbitals (from using a 2s and two 2p orbitals)': False, 'Sentence 3: Correctly states that nitrogen is hybridized': False, 'Sentence 3: Correct type of hybridization. Nitrogen is sp2 hybridized to form 3 electron domains': False, 'Sentence 3: Correct description of hybrid orbital bonds in nitrogen. Two sp2 orbitals form two sigma bonds.': False, 'Sentence 3: Correct description of unhybridized orbital bonds in nitrogen. Unhybridized p orbital forms pi bond': False}
# {'Sentence 2: Correct number of hybrid orbitals. In this molecule, carbon must form three hybrid orbitals to form three electron domains.': True, 'Sentence 2: Correct type of hybrid orbitals. Carbon must form sp2 hybrid orbitals (from using a 2s and two 2p orbitals)': True, 'Sentence 3: Correctly states that nitrogen is hybridized': True, 'Sentence 3: Correct type of hybridization. Nitrogen is sp2 hybridized to form 3 electron domains': True, 'Sentence 3: Correct description of hybrid orbital bonds in nitrogen. Two sp2 orbitals form two sigma bonds.': True, 'Sentence 3: Correct description of unhybridized orbital bonds in nitrogen. Unhybridized p orbital forms pi bond': True}
# {'Sentence 1 is correct. Valence bond theory describes that atomic orbitals must be half-filled to participate in covalent bonding.': False, 'Sentence 2: Correct number of hybrid orbitals. In this molecule, carbon must form three hybrid orbitals to form three electron domains.': False, 'Sentence 2: Correct type of hybrid orbitals. Carbon must form sp2 hybrid orbitals (from using a 2s and two 2p orbitals)': True, 'Sentence 3: Correctly states that nitrogen is hybridized': True, 'Sentence 3: Correct type of hybridization. Nitrogen is sp2 hybridized to form 3 electron domains': True, 'Sentence 3: Correct description of hybrid orbital bonds in nitrogen. Two sp2 orbitals form two sigma bonds.': False, 'Sentence 3: Correct description of unhybridized orbital bonds in nitrogen. Unhybridized p orbital forms pi bond': True}
# {'Fixed mass of one element': True, 'Mass data in LoMP': True, 'Integer/whole number ratio': True, 'Whole numbers mean indivisible/discrete': True, 'Indivisible unit of mass = atom': True}
# {'Fixed mass of one element': False, 'Mass data in LoMP': False, 'Combine to form compounds': False, 'Integer/whole number ratio': True, 'Whole numbers mean indivisible/discrete': True, 'Indivisible unit of mass = atom': False}
# {'Fixed mass of one element': True, 'Mass data in LoMP': True, 'Integer/whole number ratio': True, 'Whole numbers mean indivisible/discrete': True, 'Indivisible unit of mass = atom': True}
# {'Fixed mass of one element': False, 'Mass data in LoMP': False, 'Combine to form compounds': False, 'Integer/whole number ratio': True, 'Whole numbers mean indivisible/discrete': True, 'Indivisible unit of mass = atom': False}
# {'Combine to form compounds': True, 'Integer/whole number ratio': True, 'Whole numbers mean indivisible/discrete': True, 'Indivisible unit of mass = atom': True}
# {'Fixed mass of one element': False, 'Mass data in LoMP': False, 'Combine to form compounds': False, 'Integer/whole number ratio': False, 'Whole numbers mean indivisible/discrete': False, 'Indivisible unit of mass = atom': False}
# {'Fixed mass of one element': True, 'Mass data in LoMP': True}
# {'Fixed mass of one element': True, 'Mass data in LoMP': True, 'Combine to form compounds': True, 'Integer/whole number ratio': True, 'Whole numbers mean indivisible/discrete': True, 'Indivisible unit of mass = atom': True}
# {'Fixed mass of one element': True, 'Mass data in LoMP': True, 'Integer/whole number ratio': True, 'Whole numbers mean indivisible/discrete': True, 'Indivisible unit of mass = atom': True}
# {'Fixed mass of one element': True, 'Mass data in LoMP': True, 'Combine to form compounds': True, 'Integer/whole number ratio': True, 'Whole numbers mean indivisible/discrete': True, 'Indivisible unit of mass = atom': True}
# {'Fixed mass of one element': True, 'Mass data in LoMP': True, 'Integer/whole number ratio': True, 'Whole numbers mean indivisible/discrete': True, 'Indivisible unit of mass = atom': True}
# {'Fixed mass of one element': True, 'Mass data in LoMP': True, 'Combine to form compounds': True, 'Integer/whole number ratio': True, 'Whole numbers mean indivisible/discrete': True, 'Indivisible unit of mass = atom': False}
# falcon3-3B.json 761
# qwen3-8B.json 943
# llama32-3B.json 915
# llama32-1B.json 326
# {'Sentence 3: Correctly states that nitrogen is hybridized': True}
# {'Sentence 1 is correct. Valence bond theory describes that atomic orbitals must be half-filled to participate in covalent bonding.': False, 'Sentence 2: Correct number of hybrid orbitals. In this molecule, carbon must form three hybrid orbitals to form three electron domains.': False, 'Sentence 2: Correct type of hybrid orbitals. Carbon must form sp2 hybrid orbitals (from using a 2s and two 2p orbitals)': False, 'Sentence 3: Correctly states that nitrogen is hybridized': False, 'Sentence 3: Correct type of hybridization. Nitrogen is sp2 hybridized to form 3 electron domains': False, 'Sentence 3: Correct description of hybrid orbital bonds in nitrogen. Two sp2 orbitals form two sigma bonds.': False, 'Sentence 3: Correct description of unhybridized orbital bonds in nitrogen. Unhybridized p orbital forms pi bond': False}
# qwen3-17B.json 165
